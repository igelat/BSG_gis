# %% [markdown]
# <a href="https://colab.research.google.com/github/igelat/BSG_gis/blob/main/geopandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# installing geopandas
# !pip install geopandas

# %%
# importing geopandas
import geopandas as pdg

# %%
# reading filename
file_name = "ugandadistricts.geojson"
data = pdg.read_file(file_name)

# %%
# display data
data.head(130)
# Out:
#      OBJECTID  DCODE2014   DNAME2014  Subregion           Region  Households  \
# 0           0      314.0        Abim   KARAMOJA  NORTHERN REGION     18081.0
# 1           0      301.0    Adjumani  WEST NILE  NORTHERN REGION     41159.0
# 2           0      322.0       Agago     ACHOLI  NORTHERN REGION     43354.0
# 3           0      323.0    Alebtong      LANGO  NORTHERN REGION     46258.0
# 4           0      315.0    Amolatar      LANGO  NORTHERN REGION     27983.0
# ..        ...        ...         ...        ...              ...         ...
# 107         0      111.0  Ssembabule  CENTRAL 1   CENTRAL REGION     55185.0
# 108         0      212.0      Tororo      ELGON   EASTERN REGION    102634.0
# 109         0      113.0      Wakiso  CENTRAL 1   CENTRAL REGION    502089.0
# 110         0      313.0       Yumbe  WEST NILE  NORTHERN REGION     63362.0
# 111         0      330.0       Zombo  WEST NILE  NORTHERN REGION     50869.0
#
# ...

# %%
# access shape area
data["shape_area"]=data.Shape_Area

# %%
#setting an index
data=data.set_index("Subregion")
data["shape_Area"]=data.shape_area

# %%
#installing map classifier
# !pip install map classifier
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 2.9 MB/s eta 0:00:00
# ...
#   Created wheel for classifier: filename=classifier-2.0-py3-none-any.whl size=5029 sha256=12f4659790f98d889c7b3192360a556770df87092e22737b04dc83b2eee677ff
#   Stored in directory: /root/.cache/pip/wheels/c4/e9/f7/a0f40cc27242c7c8ef198c37bc0461f7ac90102cdbb0df7999
# Successfully built classifier
# ...

# %%
# creating an interactive map
data.plot("Shape_Area",legend=True)
# Out:
# <Axes: >

# %%
# installing leaflet
# !pip install leaflet

# %%
# display data
data.plot("Population",legend=True)
# Out:
# <Axes: >

# %%
# display data
data.plot("Urban_2014",legend=True)
# Out:
# <Axes: >

# %%
# creating an intereactive map
# !pip install mapclassify

# %%
data.explore("shape_Area", legend=True)

# %%
# quantitative analysis using describe function
data.describe()
# Out:
#        OBJECTID   DCODE2014     Households    Population    Urban_2014  \
# count     112.0  112.000000     112.000000  1.120000e+02  1.120000e+02
# mean        0.0  266.464286   65231.133929  3.092379e+05  6.630236e+04
# std         0.0  107.830191   63517.858735  2.522037e+05  1.795179e+05
# min         0.0  101.000000   13942.000000  5.429300e+04  2.952000e+03
# 25%         0.0  204.750000   34138.000000  1.771300e+05  1.381050e+04
# 50%         0.0  266.500000   47723.500000  2.397045e+05  2.804050e+04
# 75%         0.0  328.250000   76719.000000  3.893660e+05  5.843700e+04
# max         0.0  426.000000  502089.000000  1.997418e+06  1.507080e+06
#
#           Shape_Leng    Shape_Area    shape_area    shape_Area
# count     112.000000  1.120000e+02  1.120000e+02  1.120000e+02
# mean   251029.279959  2.155828e+09  2.155828e+09  2.155828e+09
# std     97864.313150  1.673161e+09  1.673161e+09  1.673161e+09
# min     70620.094362  1.951377e+08  1.951377e+08  1.951377e+08
# ...

# %%
# quantitative analysis using info function this involves data cleaning
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 112 entries, KARAMOJA to WEST NILE
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    112 non-null    int64
#  1   DCODE2014   112 non-null    float64
#  2   DNAME2014   112 non-null    object
#  3   Region      112 non-null    object
#  4   Households  112 non-null    float64
#  5   Population  112 non-null    float64
#  6   Urban_2014  112 non-null    float64
#  7   Shape_Leng  112 non-null    float64
#  8   Shape_Area  112 non-null    float64
#  9   geometry    112 non-null    geometry
#  10  shape_area  112 non-null    float64
#  11  shape_Area  112 non-null    float64
# dtypes: float64(8), geometry(1), int64(1), object(2)
# memory usage: 15.4+ KB

# %%
# projection systems
data.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# correlation matrix corr function getting a list of colums and put them in  the list use 2 square vbrackets =data[["Households","Population","Urban_2014"]].corr()
print(correleration_matrix)
# Out:
#             Households  Population  Urban_2014
# Households    1.000000    0.986602    0.890176
# Population    0.986602    1.000000    0.827821
# Urban_2014    0.890176    0.827821    1.000000

# %%
# ploting correlation matrix Nb plt has amodule of plt.bargrap, plt.pie, plt.heatmap
# figure is apaper figsize is the size of the paper
import seaborn as sbn
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.title("correlation_matrix")
sbn.heatmap(correleration_matrix, annot=True,cmap="coolwarm")
# Out:
# <Axes: title={'center': 'correlation_matrix'}>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

#generate some expample data
x= np.array([1,2,3,4,5]).reshape((-1,1))
y=np.array([2,3,4,5,6])

#creating a linear regression object
model = LinearRegression()

# fit the model to the data
model.fit(x, y)

# print the model coefficients
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# intercept: 1.0
# slope: [1.]

# %%
# make aprediction for a new data frame
x_new = np.array([6]).reshape((-1, 1))
y_new = model.predict(x_new)
print('prediction for x=6:', y_new)
# Out:
# prediction for x=6: [7.]

# %%
# data splitting into training
